# %%
import csv
import numpy as np
from scipy.integrate import quad
from numpy import *
from scipy import *

amuExp = 1165920715e-12 #116592089E-11 #
amuThe = 116592033e-11 #116591810e-11
amu = amuExp-amuThe
ErramuExp = 22e-11
ErramuThe = 43e-11
Eamu = np.sqrt(ErramuExp**2 + ErramuThe**2)
amu_up = amu+Eamu
amu_central = amu
amu, Eamu, amu_up, amu_central

import mplhep as hep 
hep.style.use(hep.style.ATLAS)

# %%
# Plotting defaults
import matplotlib as mpl
import matplotlib.pyplot as plt
linestyle_str = [
    ('solid', 'solid'), # Same as (0, ()) or '-'
    ('dotted', '.'),    # Same as (0, (1, 1)) or '.'
    ('dashed', '--'),   # Same as '--'
    ('dashdot', '-.')]  # Same as '-.'
from matplotlib.pyplot import *
from  matplotlib import *
import mplhep as hep 
hep.style.use(hep.style.ATLAS)
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (9,6)
import matplotlib.patheffects as pe
# Global Parameters in GeV units
m_mu = 0.105  # Muon mass
# Experimental Bounds
bound_current_eup = [(x, amu_up) for x in range(1, 100000)]
bound_current_central = [(x, amu_central) for x in range(1, 100000)]
sigma_current = [(x, Eamu) for x in range(1, 100000)]
#sigma_projected = [(x, 34e-11) for x in range(1, 100000)]

# %%
epsilon_1 = m_mu/m_mu 
lambda22=2.0
gs1 = lambda22/2
#I = 1j
gp1 = 0 #gs1/1j
def lambda1_func(m_mu, Mphi):
    return m_mu / Mphi
def Mphi_funcA(Vqui):
    return 0.1 * Vqui
def integrand(x, epsilon_1, lambda1, sign=1):
    return (x**2 * (1 + sign*epsilon_1 - x)) / ((1 - x) * (1 - lambda1**2 * x) + epsilon_1**2 * lambda1**2 * x)
def compute_deltaA(Vqui, m_mu):
    Mphi = Mphi_funcA(Vqui)
    lambda1_val = lambda1_func(m_mu, Mphi)
    integral_pos, _ = quad(integrand, 0, 1, args=(epsilon_1, lambda1_val, 1))
    integral_neg, _ = quad(integrand, 0, 1, args=(epsilon_1, lambda1_val, -1))
    term1 = (gs1**2 * m_mu**2) / (8 * np.pi**2 * Mphi**2) * integral_pos
    term2 = (gp1**2 * m_mu**2) / (8 * np.pi**2 * Mphi**2) * integral_neg
    return Vqui, term1 + term2
with open('DamPhiI331A.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows([compute_deltaA(Vqui, m_mu) for Vqui in range(1000, 100000, 100)])


def Mphi_funcB(Vqui):
    return 0.05 * Vqui
def compute_deltaB(Vqui, m_mu):
    Mphi = Mphi_funcB(Vqui)
    lambda1_val = lambda1_func(m_mu, Mphi)
    integral_pos, _ = quad(integrand, 0, 1, args=(epsilon_1, lambda1_val, 1))
    integral_neg, _ = quad(integrand, 0, 1, args=(epsilon_1, lambda1_val, -1))
    term1 = (gs1**2 * m_mu**2) / (8 * np.pi**2 * Mphi**2) * integral_pos
    term2 = (gp1**2 * m_mu**2) / (8 * np.pi**2 * Mphi**2) * integral_neg
    return Vqui, term1 + term2
with open('DamPhiI331B.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows([compute_deltaB(Vqui, m_mu) for Vqui in range(1000, 100000, 100)])
    
VquiA = np.genfromtxt("DamPhiI331A.csv",delimiter=",")[0:,0] 
DamPhiIA = np.genfromtxt("DamPhiI331A.csv",delimiter=",")[0:,1]
DamPhiIB = np.genfromtxt("DamPhiI331B.csv",delimiter=",")[0:,1]
DamPhiIA
#VquiI
# Out:
# array([1.75257964e-07, 1.47040962e-07, 1.25242658e-07, 1.08038281e-07,
#        9.42113451e-08, 8.29248617e-08, 7.35872080e-08, 6.57703353e-08,
#        5.91581760e-08, 5.35131268e-08, 4.86537054e-08, 4.44393092e-08,
#        4.07596053e-08, 3.75270071e-08, 3.46712510e-08, 3.21354270e-08,
#        3.46140293e-11, 3.45434466e-11, 3.44730826e-11, 3.44029366e-11,
#        3.43330075e-11, 3.42632945e-11, 3.41937968e-11, 3.41245133e-11,
#        3.40554433e-11, 3.39865858e-11, 3.39179399e-11, 3.38495048e-11,
#        3.37812797e-11, 3.37132636e-11, 3.36454557e-11, 3.35778551e-11,
#        3.35104611e-11, 3.34432726e-11, 3.33762890e-11, 3.33095093e-11,
#        3.32429328e-11, 3.31765585e-11, 3.31103858e-11, 3.30444137e-11,
#        3.29786414e-11, 3.29130681e-11, 3.28476931e-11, 3.27825155e-11,
#        3.27175344e-11, 3.26527492e-11, 3.25881591e-11, 3.25237631e-11,
#        3.24595607e-11, 3.23955508e-11, 3.23317329e-11, 3.22681061e-11,
#        3.22046697e-11, 3.21414229e-11, 3.20783649e-11, 3.20154949e-11,
#        3.19528123e-11, 3.18903163e-11, 3.18280061e-11, 3.17658810e-11,
#        3.17039402e-11, 3.16421831e-11, 3.15806088e-11, 3.15192167e-11,
#        3.14580060e-11, 3.13969761e-11, 3.13361261e-11, 3.12754555e-11,
#        3.12149634e-11, 3.11546491e-11, 3.10945121e-11, 3.10345515e-11,
#        3.09747667e-11, 3.09151570e-11, 3.08557217e-11, 3.07964601e-11,
#        3.07373715e-11, 3.06784553e-11, 3.06197108e-11, 3.05611373e-11,
#        3.05027341e-11, 3.04445006e-11])

# %%
# Plotting defaults
import matplotlib as mpl
import matplotlib.pyplot as plt
linestyle_str = [
    ('solid', 'solid'), # Same as (0, ()) or '-'
    ('dotted', '.'),    # Same as (0, (1, 1)) or '.'
    ('dashed', '--'),   # Same as '--'
    ('dashdot', '-.')]  # Same as '-.'
from matplotlib.pyplot import *
from  matplotlib import *
import mplhep as hep 
hep.style.use(hep.style.ATLAS)
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (9,6)
import matplotlib.patheffects as pe

# %% [raw]
# shadow = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
#           pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='limegreen')]
# shadow2 = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
#           pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='crimson')]
# shadow3 = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
#           pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='darkgray')]
# opt = dict(color='orchid',
#             arrowstyle = 'fancy,head_width=.5,head_length=0.5',
#             connectionstyle = 'arc3,rad=0')
# opt2 = dict(color='c',
#             arrowstyle = 'fancy,head_width=.5,head_length=0.5',
#             connectionstyle = 'arc3,rad=0')
# opt3 = dict(color='darkgray',
#             arrowstyle = 'fancy,head_width=.5,head_length=0.5',
#             connectionstyle = 'arc3,rad=0')
#
# pek2=[pe.Stroke(linewidth=1.9, foreground='k',alpha=0.5), pe.Normal()]
# pek1=[pe.Stroke(linewidth=1, foreground='limegreen',alpha=0.8), pe.Normal()]
# xLHC = np.array([5000, 5000, 5000, 5000])
# xHLLHC = np.array([11300, 11300, 11300, 11300])
# xHELHC = np.array([22300, 22300, 22300, 22300])
# x1 = np.array([100, 500, 1000, 2000, 5000])
# m1 = 0
# c1 = 10e-12
# m2 = 0
# c2 = 10e-08
# def yl1(xl1,c1,m1):
#     return (m1*xl1+c1)
# def yl2(xl1,c2,m2):
#     return (m2*xl1+c2)
# xl1=np.linspace(100, 5000, 100)
# yLHC = np.array([10**(-12), 10**(-8), 10**(-7), 10**(6)])
# plt.plot(xLHC,yLHC,'orchid',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
# plt.plot(xHLLHC,yLHC,'aqua',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
# plt.plot(xHELHC,yLHC,'darkgray',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
# #plt.text(5300, 1.1e-09, r'LHC',path_effects=shadow3,fontsize=14)
# plt.annotate('', xy=(4300,1.2e-10), xycoords='data',xytext =(4995,1.2e-10),textcoords = 'data',arrowprops=opt)#size=10)#
# plt.annotate('', xy=(9700,1.2e-10), xycoords='data',xytext =(11290,1.2e-10),textcoords = 'data',arrowprops=opt2)#size=10)#
# plt.annotate('', xy=(19500,1.2e-10), xycoords='data',xytext =(22290,1.2e-10),textcoords = 'data',arrowprops=opt3)#size=10)#
# x = np.array([100, 1000, 5000, 8000, 100000])
# plt.text(5200,1*10**(-10), r'$\it \bf LHC$',color='m',fontsize=12,rotation= 90,zorder=1)
# plt.text(11700,7*10**(-11), r'$\it \bf HL-LHC$',color='c',fontsize=12,rotation= 90,zorder=1)
# plt.text(23100,7*10**(-11),  r'$\it \bf HE-LHC $',color='darkgray',fontsize=12,rotation= 90,zorder=1)
# plt.axvspan(0, 22300, color='darkgray',alpha=0.3,edgecolor='none',zorder=0.1)
# plt.axvspan(0, 11300, color='skyblue',alpha=0.2,edgecolor='none',zorder=0.1)
# plt.axvspan(0, 5000, color='magenta',edgecolor='none',zorder=0.3,alpha=0.2)
# #BoundCurrenteup = np.array([339E-11, 339E-11, 339E-11, 339E-11, 339E-11])#
# #BoundCurrentdown= np.array([183E-11, 183E-11, 183E-11, 183E-11, 183E-11])
# sigmaCurrent = np.array([78E-11, 78E-11, 78E-11, 78E-11, 78E-11])
# sigmaProjected = np.array([34E-11, 34E-11, 34E-11, 34E-11, 34E-11])
# plt.annotate('', xy=(3*10e03,339e-11), xycoords='data',xytext =(3*10e03,183e-11),textcoords = 'data', arrowprops=dict(arrowstyle = '<->,head_width=0.25,head_length=0.25', color='limegreen',connectionstyle = 'arc3,rad=0'))
# #plt.annotate('', xy=(6*10e02,34e-11), xycoords='data',xytext =(6*10e02,78e-11),textcoords = 'data', arrowprops=dict(arrowstyle = '<->,head_width=0.25,head_length=0.25', color='crimson',connectionstyle = 'arc3,rad=0'))
# plt.text(3.2*10e03,2.2*10**(-9), r'$\Delta a_{\mu}$ Current',path_effects=shadow,fontsize=16)
# #plt.text(6.5*10e02,4.2*10**(-10), r'$\bf 1 \sigma$ bound',path_effects=shadow2,fontsize=16)
# #plt.plot(x, BoundCurrenteup,'limegreen',linestyle = 'solid',linewidth=2,markersize=0.0,zorder=0.5,path_effects=pek1)#label=r'$\Delta  a_{\mu} = 339\times 10^{-11}$',
# #plt.plot(x, BoundCurrentdown,'limegreen',linestyle = 'solid',linewidth=2,markersize=0.0,zorder=0.5,path_effects=pek1)#label=r'$\Delta  a_{\mu} = 183\times 10^{-11}$',
# plt.plot(x, sigmaCurrent,'crimson',linestyle = 'solid',linewidth=2, label=r'$\Delta  a_{\mu} < 48.3\times 10^{-11}$',markersize=0.0,zorder=0.5,path_effects=pek1)#label=r'$\Delta  a_{\mu} < 78\times 10^{-11}$'
# #plt.plot(x, sigmaProjected,'crimson',linestyle = '--',linewidth=2, label=r'$\Delta  a_{\mu} < 34\times 10^{-11}$',markersize=0.0,zorder=0.5,path_effects=pek1)#label=r'$Δ  a_{\mu} < 34\times 10^{-11}$'
# plt.plot(VquiA, DamPhiIA,'-b',linestyle = 'solid',linewidth=2,label=r'$M_{\phi}=0.1$ $v_{\chi}$', markersize=0.0,zorder=0.6,path_effects=pek1)
# plt.plot(VquiA, DamPhiIB,'-k',linestyle = 'solid',linewidth=2,label=r'$M_{\phi}=0.05$ $v_{\chi}$', markersize=0.0,zorder=0.6,path_effects=pek1)
# plt.xlim([1.0e03,1e05])
# plt.ylim([10**(-11),10**(-8)])
# plt.yscale('log')
# plt.xscale('log')
# plt.xlabel(r'$v_{\chi}$ [GeV]',loc="right")
# plt.ylabel(r'$\Delta a_{\mu} $',loc='top')
# plt.title(r'Inert scalar',fontsize=16)
# plt.legend(loc='lower left', shadow=False, fontsize=14,frameon=False,ncol=1)
# plt.savefig('331Muong-2.pdf', format='pdf', bbox_inches='tight')
# #plt.draw()
# plt.show()

# %%
mpl.rcParams['figure.figsize'] = (8,6)
shadow = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
          pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='limegreen')]
shadow2 = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
          pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='crimson')]          
shadow3 = [pe.PathPatchEffect(offset=(-1.5, 1.5), facecolor='k'),
          pe.PathPatchEffect(edgecolor='k', linewidth=0.0, facecolor='darkgray')]
opt = dict(color='orchid', 
            arrowstyle = 'fancy,head_width=.5,head_length=0.5',
            connectionstyle = 'arc3,rad=0')
opt2 = dict(color='c', 
            arrowstyle = 'fancy,head_width=.5,head_length=0.5',
            connectionstyle = 'arc3,rad=0')
opt3 = dict(color='darkgray', 
            arrowstyle = 'fancy,head_width=.5,head_length=0.5',
            connectionstyle = 'arc3,rad=0')

pek2=[pe.Stroke(linewidth=1.9, foreground='k',alpha=0.5), pe.Normal()]
pek1=[pe.Stroke(linewidth=1, foreground='limegreen',alpha=0.8), pe.Normal()]
xLHC = np.array([4000, 4000, 4000, 4000])
xHLLHC = np.array([5600,5600,5600,5600])
xHELHC = np.array([9600,9600,9600,9600])
xFCChh = np.array([27000,27000,27000,27000])
x1 = np.array([100, 500, 1000, 2000, 5000])
m1 = 0
c1 = 10e-12
m2 = 0
c2 = 10e-08
def yl1(xl1,c1,m1):
    return (m1*xl1+c1)
def yl2(xl1,c2,m2):
    return (m2*xl1+c2)
xl1=np.linspace(100, 5000, 100)
yLHC = np.array([10**(-12), 10**(-8), 10**(-7), 10**(6)])
plt.plot(xLHC,yLHC,'orchid',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
plt.plot(xHLLHC,yLHC,'aqua',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
#plt.plot(xHELHC,yLHC,'darkgray',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
plt.plot(xFCChh,yLHC,'darkgray',linestyle = '-.',lw=1, markersize=0.0,path_effects=pek2,zorder=0.5)
#plt.text(5300, 1.1e-09, r'LHC',path_effects=shadow3,fontsize=14)
plt.annotate('', xy=(3400,1e-10), xycoords='data',xytext =(4000,1e-10),textcoords = 'data',arrowprops=opt)#size=10)#
plt.annotate('', xy=(4800,1e-10), xycoords='data',xytext =(5600,1e-10),textcoords = 'data',arrowprops=opt2)#size=10)#
#plt.annotate('', xy=(8200,7e-10), xycoords='data',xytext =(9600,7e-10),textcoords = 'data',arrowprops=opt3)#size=10)#
plt.annotate('', xy=(23000,1e-10), xycoords='data',xytext =(27000,1e-10),textcoords = 'data',arrowprops=opt3)#size=10)#
x = np.array([100, 1000, 5000, 8000, 100000])
plt.text(4200,8*10**(-11), r'$\it \bf LHC$',color='m',fontsize=12,rotation= 90,zorder=1)
plt.text(5800,7*10**(-11), r'$\it \bf HL-LHC$',color='c',fontsize=12,rotation= 90,zorder=1)
#plt.text(10050,5*10**(-10),  r'$\it \bf HE-LHC $',color='darkgray',fontsize=12,rotation= 90,zorder=1)
plt.text(28000,7.5*10**(-11),  r'$\it \bf FCC-hh $',color='darkgray',fontsize=12,rotation= 90,zorder=1)
plt.axvspan(0, 27000, color='darkgray',alpha=0.3,edgecolor='none',zorder=0.1)
#plt.axvspan(0, 9600, color='darkgray',alpha=0.3,edgecolor='none',zorder=0.1)
plt.axvspan(0, 5600, color='skyblue',alpha=0.2,edgecolor='none',zorder=0.1)
plt.axvspan(0, 4000, color='magenta',edgecolor='none',zorder=0.3,alpha=0.2)
BoundCurrenteup = np.array([amu_up, amu_up, amu_up,amu_up, amu_up])
BoundCurrentdown= np.array([amu_central, amu_central, amu_central, amu_central, amu_central])
#plt.annotate('', xy=(4.1*10e03,amu_up), xycoords='data',xytext =(4.1*10e03,amu_central),textcoords = 'data', arrowprops=dict(arrowstyle = '<->,head_width=0.25,head_length=0.25', color='limegreen',connectionstyle = 'arc3,rad=0'))
#plt.text(4.4*10e03,2.4*10**(-9), r'$\Delta a_{\mu}$ Current',fontsize=14)#,path_effects=shadow,, color="limegreen"
plt.plot(x, BoundCurrenteup,'limegreen',linestyle = '--',linewidth=2,markersize=0.0,zorder=0.5,path_effects=pek1,label=r'$\Delta  a_{\mu} = 103\times 10^{-11}$')
plt.plot(x, BoundCurrentdown,'limegreen',linestyle = 'solid',linewidth=2,markersize=0.0,zorder=0.5,path_effects=pek1, label=r'$\Delta  a_{\mu} = 39\times 10^{-11}$')
plt.plot(VquiA, DamPhiIA,'-b',linestyle = 'solid',linewidth=2,label=r'$m_{\phi}=0.1$ $v_{\chi}$', markersize=0.0,zorder=0.5,path_effects=pek1)
plt.plot(VquiA, DamPhiIB,'-k',linestyle = 'solid',linewidth=2,label=r'$m_{\phi}=0.05$ $v_{\chi}$', markersize=0.0,zorder=0.5,path_effects=pek1)
plt.xlim([2.0e03,1e05])
plt.ylim([10**(-11),10**(-8)])
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'$v_{\chi}$ [GeV]',loc="right",fontsize=18)
plt.ylabel(r'$\Delta a_{\mu} $',loc='top', fontsize=18) 
plt.legend(loc='lower right', shadow=False, fontsize=16,frameon=False,ncol=2)
plt.title(r'Inert scalar',fontsize=16)
plt.savefig('331Muong-2.pdf', format='pdf', bbox_inches='tight')
#plt.draw()
plt.show()
# Out:
# /tmp/ipykernel_10299/3755674403.py:49: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(0, 27000, color='darkgray',alpha=0.3,edgecolor='none',zorder=0.1)
# /tmp/ipykernel_10299/3755674403.py:51: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(0, 5600, color='skyblue',alpha=0.2,edgecolor='none',zorder=0.1)
# /tmp/ipykernel_10299/3755674403.py:52: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(0, 4000, color='magenta',edgecolor='none',zorder=0.3,alpha=0.2)
# /tmp/ipykernel_10299/3755674403.py:59: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-b" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(VquiA, DamPhiIA,'-b',linestyle = 'solid',linewidth=2,label=r'$m_{\phi}=0.1$ $v_{\chi}$', markersize=0.0,zorder=0.5,path_effects=pek1)
# /tmp/ipykernel_10299/3755674403.py:60: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-k" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(VquiA, DamPhiIB,'-k',linestyle = 'solid',linewidth=2,label=r'$m_{\phi}=0.05$ $v_{\chi}$', markersize=0.0,zorder=0.5,path_effects=pek1)
